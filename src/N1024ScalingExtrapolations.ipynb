# %% [markdown]
# ### 3-parameter exponential fitted $\beta$-scaling

# %% [markdown]
# Want to fit observable data as a function of $\beta$ to the form:
# $$
# \mathcal{O}(\beta) = \mathcal{O}_{\beta\to\infty} + C_1 e^{-C_2 \beta}
# $$

# %% [markdown]
# where $\mathcal{O}_{\beta\to\infty}$,$C_1$, and $C_2$ are fitting parameters. The $\mathcal{O}_{\beta\to\infty}$ parameter will give a large $\beta$ extrapolation of the observable in question. Here, we will focus on the second Rényi entanglement entropy $S_2$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from scipy import optimize

# %% [markdown]
# Define the exponential model

# %%
def exponential(x, c1, c2, c3):
    return c3 + c1*np.exp(-x*c2)

# %%
# Array where extrapolated S2s will be saved to
extrapolated_S2s = np.zeros(20)
extrapolated_S2s_err = np.zeros(20)

# %% [markdown]
# Feed data points (obtained from a separate script)

# %%
betas = np.array([2,4,6,8,10,12,16,20,24]) # betas
U = 16.666667

# %%
data1 = np.loadtxt("../ProcessedData/2D_32_1024_1_16.666667_1.000000_betas_10001_S2.dat")
data2 = np.loadtxt("../ProcessedData/2D_32_1024_2_16.666667_1.000000_betas_10001_S2.dat")
data3 = np.loadtxt("../ProcessedData/2D_32_1024_3_16.666667_1.000000_betas_10001_S2.dat")
data4 = np.loadtxt("../ProcessedData/2D_32_1024_4_16.666667_1.000000_betas_10001_S2.dat")
data5 = np.loadtxt("../ProcessedData/2D_32_1024_5_16.666667_1.000000_betas_10001_S2.dat")
data6 = np.loadtxt("../ProcessedData/2D_32_1024_6_16.666667_1.000000_betas_10001_S2.dat")
data7 = np.loadtxt("../ProcessedData/2D_32_1024_7_16.666667_1.000000_betas_10001_S2.dat")
data8 = np.loadtxt("../ProcessedData/2D_32_1024_8_16.666667_1.000000_betas_10001_S2.dat")
data9 = np.loadtxt("../ProcessedData/2D_32_1024_9_16.666667_1.000000_betas_10001_S2.dat")
data10 = np.loadtxt("../ProcessedData/2D_32_1024_10_16.666667_1.000000_betas_10001_S2.dat")
data11 = np.loadtxt("../ProcessedData/2D_32_1024_11_16.666667_1.000000_betas_10001_S2.dat")
data12 = np.loadtxt("../ProcessedData/2D_32_1024_12_16.666667_1.000000_betas_10001_S2.dat")
data13 = np.loadtxt("../ProcessedData/2D_32_1024_13_16.666667_1.000000_betas_10001_S2.dat")
data14 = np.loadtxt("../ProcessedData/2D_32_1024_14_16.666667_1.000000_betas_10001_S2.dat")
data15 = np.loadtxt("../ProcessedData/2D_32_1024_15_16.666667_1.000000_betas_10001_S2.dat")
data16 = np.loadtxt("../ProcessedData/2D_32_1024_16_16.666667_1.000000_betas_10001_S2.dat")
data17 = np.loadtxt("../ProcessedData/2D_32_1024_17_16.666667_1.000000_betas_10001_S2.dat")
data18 = np.loadtxt("../ProcessedData/2D_32_1024_18_16.666667_1.000000_betas_10001_S2.dat")
data19 = np.loadtxt("../ProcessedData/2D_32_1024_19_16.666667_1.000000_betas_10001_S2.dat")
data20 = np.loadtxt("../ProcessedData/2D_32_1024_20_16.666667_1.000000_betas_10001_S2.dat")

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 1
y_array_exp = data1[:,1]
sigmas = data1[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[0] = c3
extrapolated_S2s_err[0] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.200485 +/- 0.000736

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 2
ℓ = 1
y_array_exp = data2[:,1]
sigmas = data2[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[1] = c3
extrapolated_S2s_err[1] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.467729 +/- 0.001458

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 3
ℓ = 1
y_array_exp = data3[:,1]
sigmas = data3[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[2] = c3
extrapolated_S2s_err[2] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 0.743051 +/- 0.002187

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 4
ℓ = 1
y_array_exp = data4[:,1]
sigmas = data4[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[3] = c3
extrapolated_S2s_err[3] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.020568 +/- 0.002994

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 5
ℓ = 1
y_array_exp = data5[:,1]
sigmas = data5[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[4] = c3
extrapolated_S2s_err[4] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.301311 +/- 0.003797

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 6
ℓ = 1
y_array_exp = data6[:,1]
sigmas = data6[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[5] = c3
extrapolated_S2s_err[5] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.581616 +/- 0.003558

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 7
ℓ = 1
y_array_exp = data7[:,1]
sigmas = data7[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[6] = c3
extrapolated_S2s_err[6] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 1.856576 +/- 0.003002

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 8
y_array_exp = data8[:,1]
sigmas = data8[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[7] = c3
extrapolated_S2s_err[7] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.129310 +/- 0.005021

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 9
y_array_exp = data9[:,1]
sigmas = data9[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[8] = c3
extrapolated_S2s_err[8] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.393555 +/- 0.009491

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 9
ℓ = 1
y_array_exp = data1[:,1]
sigmas = data1[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[8] = c3
extrapolated_S2s_err[8] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 10
y_array_exp = data10[:,1]
sigmas = data10[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[9] = c3
extrapolated_S2s_err[9] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.643445 +/- 0.038652

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 11
y_array_exp = data11[:,1]
sigmas = data11[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[10] = c3
extrapolated_S2s_err[10] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 2.963356 +/- 0.008708

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 12
y_array_exp = data12[:,1]
sigmas = data12[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[11] = c3
extrapolated_S2s_err[11] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 3.198600 +/- 0.022519

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 13
y_array_exp = data13[:,1]
sigmas = data13[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:-4], y_array_exp[0:-4],sigma=sigmas[0:-4],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[12] = c3
extrapolated_S2s_err[12] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit[0:],y_fit[0:],label='fit')
plt.errorbar(betas[0:5],y_array_exp[0:5], yerr=sigmas[0:5],color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 3.510893 +/- 0.003134

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 14
y_array_exp = data14[:,1]
sigmas = data14[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[13] = c3
extrapolated_S2s_err[13] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 3.762767 +/- 0.004688

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 15
y_array_exp = data15[:,1]
sigmas = data15[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[14] = c3
extrapolated_S2s_err[14] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 4.037820 +/- 0.007586

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 16
y_array_exp = data16[:,1]
sigmas = data16[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[15] = c3
extrapolated_S2s_err[15] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 4.291940 +/- 0.016241

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 17
y_array_exp = data17[:,1]
sigmas = data17[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[16] = c3
extrapolated_S2s_err[16] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 4.538892 +/- 0.019211

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 18
y_array_exp = data18[:,1]
sigmas = data18[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[1:], y_array_exp[1:],sigma=sigmas[1:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[17] = c3
extrapolated_S2s_err[17] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 4.766678 +/- 0.013729

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 19
y_array_exp = data19[:,1]
sigmas = data19[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[18] = c3
extrapolated_S2s_err[18] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 5.010169 +/- 0.012275

# %%
# Obtained with entanglement_combiner.py for betas
ℓ = 20
y_array_exp = data20[:,1]
sigmas = data20[:,2]

# Perform 3-parameter exponential fit
popt_exponential, pcov_exponential = scipy.optimize.curve_fit(exponential, betas[0:], y_array_exp[0:],sigma=sigmas[0:],p0=[0.9,0.1,y_array_exp[-1]])

# Extract fit parameters
c1,c2,c3 = popt_exponential
c3_err = np.sqrt(np.diag(pcov_exponential)[2])

extrapolated_S2s[19] = c3
extrapolated_S2s_err[19] = c3_err

# Perform the fit
betas_fit = np.linspace(min(betas),max(betas)*1,1000)
y_fit = exponential(betas_fit,c1,c2,c3)

plt.plot(betas_fit,y_fit,label='fit')
plt.errorbar(betas,y_array_exp, yerr=sigmas,color='red',marker='o',label='data',fmt='.',
            capsize=5)
plt.ylabel(r"$S_2$")
plt.xlabel(r"$\beta$")
plt.legend(frameon=False);

print("S2 (extrapolated) \n")
print(f"{c3:0.6f} +/- {c3_err:0.6f}")
# Out:
# S2 (extrapolated)
#
# 5.229864 +/- 0.012472

# %% [markdown]
# Perform exponential fit to data with Scipy curve_fit

# %%
print(list(extrapolated_S2s))
print(list(extrapolated_S2s_err))
# Out:
# [0.2004848712448062, 0.4677294184760275, 0.7430512402769539, 1.0205679224465791, 1.3013113138840737, 1.5816157906273685, 1.85657563669291, 2.129309963787313, 2.393555002135601, 2.6434445931661017, 2.963356237417265, 3.198600173041978, 3.510892656539231, 3.762766622527445, 4.037819843848105, 4.291940357531262, 4.538891865568787, 4.766677671983685, 5.0101692302426555, 5.229863999510719]
# [0.0007358784816848723, 0.0014575908978724317, 0.0021872381393161053, 0.0029936086002056894, 0.0037973574245099813, 0.0035584744018016456, 0.0030018774147782716, 0.0050213722064983615, 0.009491121776931684, 0.03865237953974337, 0.008708049182060158, 0.02251935546770281, 0.003134172793016746, 0.004687982959053907, 0.0075860151888975545, 0.01624121640036146, 0.019210935981856265, 0.013728645706053668, 0.012275232692621976, 0.012472399517726543]

# %%
# Save the extrapolations to file here
# Save the extrapolations to file here
D=2
L=32
N=1024
l_max=20
t=1.000000
bin_size=10001
U = 16.666667
beta_list = np.array(betas)
ℓ_list = np.array(list(range(1,21)))
#Format the data file
with open("../ProcessedData/"+str(D)+"D_%d_%d_ls_%.6f_%.6f_extrapolations_%d_S2.dat"%(L,N,U,t,bin_size),"wb") as processed_data:
    np.savetxt(processed_data,np.c_[ℓ_list,extrapolated_S2s,extrapolated_S2s_err],delimiter=" ",fmt="%.16f",header="BH Parameters: L=%d,N=%d,D=%d,U=%.6f,t=%.6f,beta=extrapolations,bin_size=%d \n U               <S2>               StdErr."%(L,N,D,U,t,bin_size))
